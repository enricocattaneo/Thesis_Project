# %% [markdown]
# #### Imports

# %%
# Packages
import numpy as np
import pandas as pd
from datetime import datetime
import os
# Pandas' options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## **PREPARE TEAMS' ATTRIBUTES DATA**

# %% [markdown]
# #### Import Different Data Sources

# %%
def concatenate_csv_in_directory(path_IN, path_OUT, write_OUTFILE):
    if os.path.isfile(path_OUT):
        appended_data = pd.read_csv(path_OUT)
    else:    
        appended_data = [pd.read_csv(os.path.join(path_IN, file)) for file in os.listdir(path_IN) if file.endswith('.csv')]
        appended_data = pd.concat(appended_data)
    if write_OUTFILE:
        appended_data.to_csv(path_OUT)
    return appended_data

# %% [markdown]
# ###### **concatenate_csv_in_directory()**: Import chunks of in the same directory and concatenates them. ***path_IN*** is the path of the directory where the data can be found. ***path_OUT*** is the path (including filename) of the output file. ***write_OUTFILE*** if True it saves the data into a CSV file, if False it only creates a dataframe in pandas

# %%
# Import CSV of weekly data (major leagues)
tm_w_MAJOR = pd.read_csv('../Data/Scraping FIFA/Dirty data/Teamdata_weekly.csv')
tm_w_MAJOR['is_major'] = 1
# Import CSV of weekly data (Minor leagues)
tm_MINOR = pd.read_csv('../Data/Scraping FIFA/Dirty data/TeamData_weekly_MINOR.csv')
tm_MINOR['is_major'] = 0
# Import CSV of weekly data (new observations)
tm_w_new = pd.read_csv('../Data/Scraping FIFA/Dirty data/Teamdata_weekly_NEW.csv')
tm_w_new['is_major'] = 1
tm_15_MAJ =  pd.read_csv('../Data/Scraping FIFA/Dirty data/Teamdata_weekly_NEW_15_MAJ.csv')
tm_15_MAJ['is_major'] = 1
tm_15_MIN =  pd.read_csv('../Data/Scraping FIFA/Dirty data/Teamdata_weekly_NEW_15_MIN.csv')
tm_15_MIN['is_major'] = 0
# Concatenate the previous dataframes
tm_weekly = pd.concat([tm_w_MAJOR, tm_MINOR, tm_w_new, tm_15_MAJ, tm_15_MIN])

# %% [markdown]
# #### Cleaning of Team Attributes Data

# %%
# Exclude data from FIFA10 and FIFA11
tm_weekly = tm_weekly[(tm_weekly['ObservationDate'] != 'Sept. 1, 2009') & (tm_weekly['ObservationDate'] != 'Sept. 1, 2010')] 
# Change ObservationDate to Date Format
tm_weekly['ObservationDate'] = tm_weekly['ObservationDate'].str.replace('Sept', 'Sep')
tm_weekly['ObservationDate'] = tm_weekly['ObservationDate'].str.replace('April', 'Apr.')
tm_weekly['ObservationDate'] = tm_weekly['ObservationDate'].str.replace('June', 'Jun.')
tm_weekly['ObservationDate'] = tm_weekly['ObservationDate'].str.replace('March', 'Mar.')
tm_weekly['ObservationDate'] = tm_weekly['ObservationDate'].str.replace('May', 'May.')
tm_weekly['ObservationDate'] = tm_weekly['ObservationDate'].str.replace('July', 'Jul.')
tm_weekly['ObservationDate'] = tm_weekly['ObservationDate'].map(lambda x: datetime.strptime(x, '%b. %d, %Y'))
# Keep only some columns (most columns dropped have too many NA) + Sort by Date and TeamName
tm_weekly = tm_weekly[['ObservationDate', 'TeamName', 'Attack', 'Midfield', 'Defence', 'TransferBudget', 'RivalTeam', 'TeamRoster', 'is_major']]
tm_weekly = tm_weekly.sort_values(by = ['ObservationDate', 'TeamName']).reset_index(drop = True)
tm_weekly16 = tm_weekly[tm_weekly['ObservationDate'] > '2015-05-01']
tm_weekly16 = tm_weekly16.sort_values(by="ObservationDate")
tm_weekly16.head()
# Out:
#     ObservationDate                TeamName  Attack  Midfield  Defence  \
# 595      2015-07-10        1. FC Heidenheim      65        63       64
# 725      2015-07-10      Olympique Lyonnais      78        75       74
# 726      2015-07-10  Olympique de Marseille      77        75       75
# 727      2015-07-10                 Palermo      73        72       72
# 728      2015-07-10     Paris Saint-Germain      82        81       80
#
#      TransferBudget               RivalTeam  \
# 595          500000               VfR Aalen
# 725        13000000        AS Saint-Etienne
# 726        15000000     Paris Saint-Germain
# 727         9000000                 Catania
# 728       120000000  Olympique de Marseille
#
#                                             TeamRoster  is_major
# 595  ['Jan Zimmermann', 'Robert Strauß', 'Tim Göhle...         0
# 725  ['Anthony Lopes', 'Mouhamadou Dabo', 'Lindsay ...         1
# 726  ['Steve Mandanda', 'Brice Dja Djédjé', 'Rod Fa...         1
# 727  ['Samir Ujkani', 'Roberto Vitiello', 'Giancarl...         1
# 728  ['Nicolas Douchez', 'Marquinhos', 'Thiago Silv...         1

# %%
teams_name_repl = {'1. ':'','AS Monaco Football Club SA':'Monaco','Monaco Football Club SA':'AS Monaco Football Club SA','AS Monaco':'Monaco','AS Nancy-Lorraine':'Nancy', 'AS Saint-Étienne':'Saint-Étienne','Amiens SC Football': 'Amiens SC',  'Arminia Bielefeld':'DSC Arminia Bielefeld', 'Athletic Club de Bilbao':'Athletic Club', 'Atlético de Madrid': 'Atlético Madrid', 'Bergamo Calcio':'Atalanta', "Borussia M'gladbach": 'Borussia Mönchengladbach', 'Bournemouth':'AFC Bournemouth','CA Osasuna':'Osasuna', 'CD Leganés':'Leganés', 'Chievo Verona':'Chievo', 'Clermont Foot':'Clermont', 'Cádiz CF':'Cádiz', 'D. Alavés':'Deportivo Alavés', 'Dijon FCO': 'Dijon', 'ES Troyes AC':'Troyes', 'ESTAC Troyes':'Troyes', 'Elche CF':'Elche', 'En Avant de Guingamp':'Guingamp', 'FC Bayern Munich':'FC Bayern München', 'Bayern München':'FC Bayern München', 'FC Girondins de Bordeaux':'Bordeaux', 'FC Ingolstadt 04':'Ingolstadt', 'FC Lorient':'Lorient', 'FC Metz':'Metz', 'FC Nantes':'Nantes', 'FC Nürnberg':'Nürnberg', 'FC Schalke 04':'Schalke 04', 'Football Club de Metz':'Metz', 'GFC Ajaccio':'Gazélec Ajaccio', 'Getafe CF':'Getafe', 'Girona CF':'Girona', 'Girona FC':'Girona', 'Girondins de Bordeaux':'Bordeaux', 'Granada CF':'Granada', 'Hertha BSC Berlin':'Hertha BSC', 'Hertha Berlin':'Hertha BSC', 'LOSC Lille':'Lille', 'La Spezia':'Spezia', 'Latium':'Lazio', 'Levante UD':'Levante', 'Montpellier HSC':'Montpellier', 'Montpellier Hérault SC':'Montpellier', 'Málaga CF':'Málaga', 'Nîmes Olympique':'Nîmes', 'OGC Nice':'Nice', 'Olympique de Marseille':'Olympique Marseille', 'Paris Saint-Germain':'Paris Saint Germain', 'R. Valladolid CF':'Real Valladolid', 
'Celta de Vigo de Vigo':'Celta de Vigo', 'RC Celta de Vigo':'Celta de Vigo', 'RC Celta':'Celta de Vigo', 'RC Deportivo de La Coruña':'Deportivo La Coruña', 'RC Lens':'Lens', 'RC Strasbourg Alsace':'Strasbourg','Strasbourg Alsace':'Strasbourg','RC Strasbourg':'Strasbourg', 'RCD Espanyol':'Espanyol', 'RCD Mallorca':'Mallorca', 'Real Betis Balompié':'Real Betis', 'Real Madrid CF':'Real Madrid', 'Real Sporting de Gijón':'Sporting Gijón', 'SC Bastia':'Bastia', 'SC Paderborn 07':'Paderborn', 'SD Huesca':'Huesca', 'SM Caen':'Caen', 'SV Darmstadt 98':'Darmstadt 98', 'SV Werder Bremen':'Werder Bremen', 'Sevilla FC':'Sevilla', 'Spal':'SPAL', 'Sport-Club Freiburg':'SC Freiburg', 'Stade Brestois 29':'Brest', 'Stade Malherbe Caen':'Caen', 'Stade Rennais FC':'Rennes','Stade Rennais':'Rennes','Rennes FC':'Rennes', 'Stade de Reims':'Reims', 'TSG 1899 Hoffenheim':'TSG Hoffenheim', 'Toulouse FC':'Toulouse', 'Toulouse Football Club':'Toulouse', 'UD Las Palmas':'Las Palmas', 'Valencia CF':'Valencia', 'VfL Bochum':'VfL Bochum 1848', 'Villarreal CF':'Villarreal', 'AFC AFC Bournemouth':'AFC Bournemouth', 'DSC DSC Arminia Bielefeld':'DSC Arminia Bielefeld', 'FC FC Bayern München':'FC Bayern München', '1899 Hoffenheim':'TSG Hoffenheim', 'ACF Fiorentina':'Fiorentina', 'AS Saint-Etienne':'Saint-Étienne', 'Club Atlético Madrid':'Atlético Madrid', 'Elche Club de Fútbol':'Elche', 'Espanyol de Barcelona':'Espanyol', 'Getafe Club de Fútbol':'Getafe', 'Granada Club de Fútbol':'Granada', 'Levante Unión Deportiva':'Levante', 'Lorient Bretagne Sud':'Lorient', 'Monaco FC':'Monaco', 'Montpellier Hérault Sport Club':'Montpellier', 'Málaga Club de Fútbol':'Málaga', 'Queens Park Rangers':'Crystal Palace', 'Racing Club de Lens':'Lens', 'Rayo Vallecano de Madrid':'Rayo Vallecano', 'Real Club Celta de Vigo':'Celta de Vigo', 'Real Club Deportivo de La Coruña':'Deportivo La Coruña', 'Real Madrid Club de Fútbol':'Real Madrid', 'Real Sociedad de Fútbol':'Real Sociedad', 'Sevilla Fútbol Club':'Sevilla', 'Sporting Club Bastia':'Bastia', 'VfL Bochum 1848 1848':'VfL Bochum 1848', 'Valencia Club de Fútbol':'Valencia', 'Villarreal Club de Fútbol':'Villarreal', 'AC Ajaccio':'Gazélec Ajaccio', 'AS Nancy':'Nancy', 'AS Nancy Lorraine':'Nancy', 'Athlétic Club Ajaccio':'Gazélec Ajaccio',  'Bilbao Athletic':'Athletic Club', 'Clermont 63':'Clermont', 'Clermont Auvergne 63':'Clermont', 'Club Atlético Osasuna':'Osasuna', 'Club Deportivo Leganés':'Leganés'}

for old, new in teams_name_repl.items():
    tm_weekly16['TeamName'] = tm_weekly16['TeamName'].str.replace(old, new, regex=False)

# %% [markdown]
# ### Prepare MATCH DATA

# %%
# Import CSV
match_data = pd.read_csv('../Data/Match&Odds Data/matchdata_2015_out.csv', low_memory=False)
# Set Fixture id as index
match_data.set_index('id', inplace=True)
#### Change data types ####
float_columns = ['weather_report_pressure', 'weather_report_temperature_celcius_temp', 'weather_report_wind_degree', 'weather_windspeed(m/s)', 'home_passes_percentage', 'away_passes_percentage'] # columns that will be floats
# Convert all numeric columns to int except those that are expressed in floats
match_data[['weather_windspeed(m/s)', 'weather_clouds(%)', 'weather_humidity(%)']] = match_data[['weather_windspeed(m/s)', 'weather_clouds(%)', 'weather_humidity(%)']].astype('float64')       
m = match_data.select_dtypes(np.number).loc[:, ~match_data.select_dtypes(np.number).columns.isin(float_columns)]
match_data[m.columns]= m.round().astype('Int64')
# Convert dates to datetime format
match_data['time_starting_at_date_time'] = pd.to_datetime(match_data['time_starting_at_date_time'], infer_datetime_format=True)
match_data['round_start'] = pd.to_datetime(match_data['round_start'], format = '%Y-%m-%d')
match_data['round_end'] = pd.to_datetime(match_data['round_end'], format = '%Y-%m-%d')
match_data = match_data[match_data['league_is_cup'] == 0]
match_data = match_data.sort_values(by='time_starting_at_date_time')

# %%
match_data.head()
# Out:
#         league_id  season_id  stage_id  round_id  venue_id  referee_id  \
# id
# 251711        301       1390      2497     37918       184       48975
# 849             8         10         8        85       206       13533
# 864             8         10         8        85       489       14663
# 871             8         10         8        85       117       15270
# 879             8         10         8        85        12       15272
#
#         home_id  away_id  winner_team_id  attendance  \
# id
# 251711      690      591             591        <NA>
# 849          14        6              14       75261
# 864          33       51              51       27036
# 871          42        3              42       32242
# 879          13       25            <NA>       39063
#
#        formations_home_formation formations_away_formation  scores_home_score  \
# id
# 251711                       NaN                       NaN                  0
# 849                          NaN                       NaN                  1
# 864                          NaN                       NaN                  1
# 871                          NaN                       NaN                  4
# 879                          NaN                       NaN                  2
#
#         scores_away_score scores_ht_score scores_ft_score  \
# id
# 251711                  1             0-0             0-1
# 849                     0             1-0             1-0
# 864                     3             0-1             1-3
# 871                     2             3-0             4-2
# 879                     2             0-1             2-2
#
#        time_starting_at_date_time  time_minute  time_injury_time  \
# id
# 251711        2015-08-07 20:30:00           90              <NA>
# 849           2015-08-08 13:45:00           90              <NA>
# 864           2015-08-08 16:00:00           90              <NA>
# 871           2015-08-08 16:00:00           90              <NA>
# 879           2015-08-08 16:00:00           90              <NA>
#
#         coaches_home_coach_id  coaches_away_coach_id  standings_home_position  \
# id
# 251711                 474402               37438919                     <NA>
# 849                  37523072                 455358                     <NA>
# 864                    173023                 896470                     <NA>
# 871                    893654                 523970                     <NA>
# 879                    474796                 455821                     <NA>
#
#         standings_away_position  assistants_first_assistant_id  \
# id
# 251711                     <NA>                          12852
# 849                        <NA>                          13561
# 864                        <NA>                          12088
# 871                        <NA>                          12146
# 879                        <NA>                          12018
#
#         assistants_second_assistant_id  assistants_fourth_official_id  \
# id
# 251711                           18518                          15934
# 849                              12245                          14533
# 864                              12147                          15271
# 871                              12090                          15241
# 879                              12091                          14532
#
#                 home_name home_short_code    home_twitter  home_country_id  \
# id
# 251711              Lille             LIL       @losclive               17
# 849     Manchester United             MUN         @ManUtd              462
# 864          Norwich City             NOR  @NorwichCityFC              462
# 871        Leicester City             LEI           @LCFC              462
# 879               Everton             EVE        @Everton              462
#
#         home_founded  home_venue_id            away_name away_short_code  \
# id
# 251711          1944            184  Paris Saint Germain             PSG
# 849             1878            206    Tottenham Hotspur             TOT
# 864             1902            489       Crystal Palace             CRY
# 871             1884            117           Sunderland             SUN
# 879             1878             12              Watford             WAT
#
#           away_twitter  away_country_id  away_founded  away_venue_id  \
# id
# 251711     @PSG_inside               17          1970            131
# 849     @SpursOfficial              462          1882         281313
# 864              @CPFC              462          1905            201
# 871                NaN              462          1879            212
# 879         @WatfordFC              462          1881             19
#
#         league_country_id     league_name  league_is_cup season_name  \
# id
# 251711                 17         Ligue 1              0   2015/2016
# 849                   462  Premier League              0   2015/2016
# 864                   462  Premier League              0   2015/2016
# 871                   462  Premier League              0   2015/2016
# 879                   462  Premier League              0   2015/2016
#
#         season_league_id  current_season  round_name  round_league_id  \
# id
# 251711               301               0           1              301
# 849                    8               0           1                8
# 864                    8               0           1                8
# 871                    8               0           1                8
# 879                    8               0           1                8
#
#         round_season_id  round_stage_id round_start  round_end  \
# id
# 251711             1390            2497  2015-08-07 2015-08-09
# 849                  10               8  2015-08-08 2015-08-10
# 864                  10               8  2015-08-08 2015-08-10
# 871                  10               8  2015-08-08 2015-08-10
# 879                  10               8  2015-08-08 2015-08-10
#
#                  venue_name  venue_grass_surface         venue_city  \
# id
# 251711  Stade Pierre-Mauroy                    1  Villeneuve d'Ascq
# 849            Old Trafford                    1         Manchester
# 864             Carrow Road                    1            Norwich
# 871      King Power Stadium                    1          Leicester
# 879           Goodison Park                    1          Liverpool
#
#         venue_capacity      venue_coordinates referee_fullname  \
# id
# 251711           50186   (50.631111,3.137500)    Fredy Fautrel
# 849              75635  (53.463150,-2.291444)    Jonathan Moss
# 864              27244    (52.622116,1.30914)     Simon Hooper
# 871              32312  (52.620278,-1.142222)        Lee Mason
# 879              40569  (53.438801,-2.966328)       Mike Jones
#
#         homecoach_coach_id  homecoach_team_id  homecoach_country_id  \
# id
# 251711              474402              18562                    17
# 849               37523072              18694                    38
# 864                 173023                  3                  1161
# 871                 893654               <NA>                   251
# 879                 474796              18743                    32
#
#                homecoach_fullname homecoach_nationality homecoach_birthdate  \
# id
# 251711               Hervé Renard                France          30/09/1968
# 849                Louis van Gaal           Netherlands          08/08/1951
# 864                     Alex Neil              Scotland          09/06/1981
# 871               Claudio Ranieri                 Italy          20/10/1951
# 879     Roberto Martínez Montoliú                 Spain          13/07/1973
#
#        homecoach_birthcountry homecoach_birthplace  Awaycoach_coach_id  \
# id
# 251711                 France        Aix-les-Bains            37438919
# 849               Netherlands            Amsterdam              455358
# 864                  Scotland             Belshill              896470
# 871                     Italy                 Roma              523970
# 879                     Spain             Balaguer              455821
#
#         Awaycoach_team_id  Awaycoach_country_id  \
# id
# 251711              13260                    17
# 849                   591                    44
# 864                  <NA>                   462
# 871                 18600                    38
# 879                   106                    32
#
#                           Awaycoach_fullname Awaycoach_nationality  \
# id
# 251711                         Laurent Blanc                France
# 849     Mauricio Roberto Pochettino Trossero             Argentina
# 864                              Alan Pardew               England
# 871                            Dick Advocaat           Netherlands
# 879                   Enrique Sánchez Flores                 Spain
#
#        Awaycoach_birthdate Awaycoach_birthcountry Awaycoach_birthplace  \
# id
# 251711          19/11/1965                 France                 Ales
# 849             02/03/1972              Argentina               Murphy
# 864             18/07/1961                England               London
# 871             27/09/1947            Netherlands             Den Haag
# 879             05/02/1965                  Spain               Madrid
#
#        weather_report_code weather_report_type  weather_windspeed(m/s)  \
# id
# 251711                 NaN                 NaN                     NaN
# 849                    NaN                 NaN                     NaN
# 864                    NaN                 NaN                     NaN
# 871                    NaN                 NaN                     NaN
# 879                    NaN                 NaN                     NaN
#
#         weather_report_wind_degree  weather_clouds(%)  weather_humidity(%)  \
# id
# 251711                         NaN               <NA>                 <NA>
# 849                            NaN               <NA>                 <NA>
# 864                            NaN               <NA>                 <NA>
# 871                            NaN               <NA>                 <NA>
# 879                            NaN               <NA>                 <NA>
#
#        colors_home_color colors_away_color  weather_report_pressure  \
# id
# 251711               NaN               NaN                      NaN
# 849                  NaN               NaN                      NaN
# 864                  NaN               NaN                      NaN
# 871                  NaN               NaN                      NaN
# 879                  NaN               NaN                      NaN
#
#         weather_report_temperature_celcius_temp  home_team_id  \
# id
# 251711                                      NaN           690
# 849                                         NaN            14
# 864                                         NaN            33
# 871                                         NaN            42
# 879                                         NaN            13
#
#         home_fixture_id  home_shots_total  home_shots_ongoal  \
# id
# 251711           251711                12                  2
# 849                 849                 9                  1
# 864                 864                17                  6
# 871                 871                19                  8
# 879                 879                10                  5
#
#         home_shots_offgoal  home_shots_blocked  home_shots_insidebox  \
# id
# 251711                   0                   0                     0
# 849                      0                   0                     0
# 864                      0                   0                     0
# 871                      0                   0                     0
# 879                      0                   0                     0
#
#         home_shots_outsidebox  home_passes  home_attacks  home_fouls  \
# id
# 251711                      0         <NA>          <NA>          20
# 849                         0         <NA>          <NA>          12
# 864                         0         <NA>          <NA>          14
# 871                         0         <NA>          <NA>          13
# 879                         0         <NA>          <NA>           7
#
#         home_corners  home_offsides  home_possessiontime  home_yellowcards  \
# id
# 251711             3           <NA>                   52                 3
# 849                1              1                   50                 2
# 864                1              4                   63                 1
# 871                6           <NA>                   44                 2
# 879                8              4                   67                 1
#
#         home_redcards  home_yellowredcards  home_saves  home_substitutions  \
# id
# 251711           <NA>                 <NA>           1                <NA>
# 849              <NA>                 <NA>           4                <NA>
# 864              <NA>                 <NA>           4                <NA>
# 871              <NA>                 <NA>           3                <NA>
# 879              <NA>                 <NA>           3                <NA>
#
#         home_goal_kick  home_goal_attempts  home_free_kick  home_throw_in  \
# id
# 251711            <NA>                <NA>            <NA>           <NA>
# 849               <NA>                <NA>            <NA>           <NA>
# 864               <NA>                <NA>            <NA>           <NA>
# 871               <NA>                <NA>            <NA>           <NA>
# 879               <NA>                <NA>            <NA>           <NA>
#
#         home_ball_safe  home_goals  home_penalties  home_injuries  \
# id
# 251711            <NA>        <NA>            <NA>           <NA>
# 849               <NA>        <NA>            <NA>           <NA>
# 864               <NA>        <NA>            <NA>           <NA>
# 871               <NA>        <NA>            <NA>           <NA>
# 879               <NA>        <NA>            <NA>           <NA>
#
#         home_tackles  away_team_id  away_fixture_id  away_shots_total  \
# id
# 251711          <NA>           591           251711                 7
# 849             <NA>             6              849                 9
# 864             <NA>            51              864                11
# 871             <NA>             3              871                11
# 879             <NA>            25              879                11
#
#         away_shots_ongoal  away_shots_offgoal  away_shots_blocked  \
# id
# 251711                  2                   0                   0
# 849                     4                   0                   0
# 864                     7                   0                   0
# 871                     5                   0                   0
# 879                     5                   0                   0
#
#         away_shots_insidebox  away_shots_outsidebox  away_passes  \
# id
# 251711                     0                      0         <NA>
# 849                        0                      0         <NA>
# 864                        0                      0         <NA>
# 871                        0                      0         <NA>
# 879                        0                      0         <NA>
#
#         away_attacks  away_fouls  away_corners  away_offsides  \
# id
# 251711          <NA>          17             2              2
# 849             <NA>          12             2              2
# 864             <NA>          20             4              2
# 871             <NA>          17             3              1
# 879             <NA>          13             2              1
#
#         away_possessiontime  away_yellowcards  away_redcards  \
# id
# 251711                   48                 2              1
# 849                      50                 3           <NA>
# 864                      37              <NA>           <NA>
# 871                      56                 4           <NA>
# 879                      33                 2           <NA>
#
#         away_yellowredcards  away_saves  away_substitutions  away_goal_kick  \
# id
# 251711                 <NA>           2                <NA>            <NA>
# 849                    <NA>           1                <NA>            <NA>
# 864                    <NA>           5                <NA>            <NA>
# 871                    <NA>           4                <NA>            <NA>
# 879                    <NA>           3                <NA>            <NA>
#
#         away_goal_attempts  away_free_kick  away_throw_in  away_ball_safe  \
# id
# 251711                <NA>            <NA>           <NA>            <NA>
# 849                   <NA>            <NA>           <NA>            <NA>
# 864                   <NA>            <NA>           <NA>            <NA>
# 871                   <NA>            <NA>           <NA>            <NA>
# 879                   <NA>            <NA>           <NA>            <NA>
#
#         away_goals  away_penalties  away_injuries  away_tackles  \
# id
# 251711        <NA>            <NA>           <NA>          <NA>
# 849           <NA>            <NA>           <NA>          <NA>
# 864           <NA>            <NA>           <NA>          <NA>
# 871           <NA>            <NA>           <NA>          <NA>
# 879           <NA>            <NA>           <NA>          <NA>
#
#         home_passes_total  home_passes_accurate  home_passes_percentage  \
# id
# 251711               <NA>                  <NA>                     NaN
# 849                  <NA>                  <NA>                     NaN
# 864                  <NA>                  <NA>                     NaN
# 871                  <NA>                  <NA>                     NaN
# 879                  <NA>                  <NA>                     NaN
#
#         away_passes_total  away_passes_accurate  away_passes_percentage  \
# id
# 251711               <NA>                  <NA>                     NaN
# 849                  <NA>                  <NA>                     NaN
# 864                  <NA>                  <NA>                     NaN
# 871                  <NA>                  <NA>                     NaN
# 879                  <NA>                  <NA>                     NaN
#
#         home_attacks_attacks  home_attacks_dangerous_attacks  \
# id
# 251711                  <NA>                            <NA>
# 849                     <NA>                            <NA>
# 864                     <NA>                            <NA>
# 871                     <NA>                            <NA>
# 879                     <NA>                            <NA>
#
#         away_attacks_attacks  away_attacks_dangerous_attacks  home_shots  \
# id
# 251711                  <NA>                            <NA>        <NA>
# 849                     <NA>                            <NA>        <NA>
# 864                     <NA>                            <NA>        <NA>
# 871                     <NA>                            <NA>        <NA>
# 879                     <NA>                            <NA>        <NA>
#
#         away_shots weather_lat_lon
# id
# 251711        <NA>      (nan, nan)
# 849           <NA>      (nan, nan)
# 864           <NA>      (nan, nan)
# 871           <NA>      (nan, nan)
# 879           <NA>      (nan, nan)

# %% [markdown]
# # **Create New Team Attributes Dataframe**

# %%
from tqdm.notebook import tqdm

# %%
def test_merge(df, homeORaway):
    if homeORaway == 'home':
        print('****** TEST ', homeORaway.upper(), ' ******')
        print('Name Errors = ', (df['home_name'] != df['Home_TeamName']).sum())
        print('Date Errors = ', (df['Home_ObservationDate'] > df['time_starting_at_date_time']).sum())
    elif homeORaway == 'away': 
        print('****** TEST ', homeORaway.upper(), ' ******')
        print('Name Errors = ', (df['away_name'] != df['Away_TeamName']).sum())
        print('Date Errors = ', (df['Away_ObservationDate'] > df['time_starting_at_date_time']).sum())
    else:
        print('BAD TEST!!')

# %%
match_data = match_data.reset_index()
for h_a in ['home_name', 'away_name']:
    all_ordered = []
    for index, i in enumerate(tqdm(match_data.time_starting_at_date_time)):
        time_d = [(i.date() - j.date()).days if (i.date() - j.date()).days >= 1 and match_data[h_a].iloc[index] == tm_weekly16.TeamName.iloc[ind] else 999 for ind, j in enumerate(tm_weekly16.ObservationDate)]
        index_min = min(range(len(time_d)), key=time_d.__getitem__)

        if index_min == 0 and match_data[h_a].iloc[index_min] != tm_weekly16.TeamName.iloc[0]:
            time_d_exrelegated = [(i.date() - j.date()).days if (i.date() - j.date()).days < 0 and match_data[h_a].iloc[index] == tm_weekly16.TeamName.iloc[ind] else -999 for ind, j in enumerate(tm_weekly16.ObservationDate)]
            index_max = max(range(len(time_d_exrelegated)), key=time_d_exrelegated.__getitem__)
            all_ordered.append(dict(tm_weekly16.iloc[index_max,:]))
        else:
            all_ordered.append(dict(tm_weekly16.iloc[index_min,:]))
            
    if h_a == 'home_name':
        new_df_home = pd.DataFrame(all_ordered).add_prefix('Home_')
        merge1 = pd.merge(match_data, new_df_home, how='outer', left_index=True, right_index=True)
        test_merge(merge1, 'home')
    elif h_a == 'away_name':
        new_df_away = pd.DataFrame(all_ordered).add_prefix('Away_')
        final_merged = pd.merge(merge1, new_df_away, how='outer', left_index=True, right_index=True)
        test_merge(final_merged, 'home')
        test_merge(final_merged, 'away')
# Out:
#   0%|          | 0/12362 [00:00<?, ?it/s]
# ****** TEST  HOME  ******
# Name Errors =  0
# Date Errors =  3
#   0%|          | 0/12362 [00:00<?, ?it/s]
# ****** TEST  HOME  ******
# Name Errors =  0
# Date Errors =  3
# ****** TEST  AWAY  ******
# Name Errors =  0
# Date Errors =  4

# %% [markdown]
# **NOTES:** To avoid problems with teams coming from a minor league we consider the case of the index_min taking the value 0 and the team name from match data not matching the team name on tm_weekly16, in this case we consider the attributes of the right team but coming from the closest observation in the future (instead that from the past). This problem could be avoided through scraping also data from the minor leagues!

# %%
final_merged.tail()
# Out:
#              id  league_id  season_id  stage_id  round_id  venue_id  \
# 12357  18165757        564      18462  77454016    250046    304396
# 12358  18220188        384      18576  77454372    252815      7305
# 12359  18220185        384      18576  77454372    252815      1721
# 12360  18157344        301      18441  77453967    249532       135
# 12361  18165743        564      18462  77454016    250047       133
#
#        referee_id  home_id  away_id  winner_team_id  attendance  \
# 12357       18637      377      214            <NA>        <NA>
# 12358       15969      345     2930            2930        <NA>
# 12359       13970      113      102             113        <NA>
# 12360       15484      598     6789            6789        <NA>
# 12361       13963      594      485            <NA>        <NA>
#
#       formations_home_formation formations_away_formation  scores_home_score  \
# 12357                   4-2-3-1                   4-1-4-1                  1
# 12358                   4-2-3-1                     3-5-2                  1
# 12359                     4-3-3                   4-3-2-1                  2
# 12360                   4-2-3-1                   4-2-3-1                  2
# 12361                   4-3-1-2                   4-2-3-1                  0
#
#        scores_away_score scores_ht_score scores_ft_score  \
# 12357                  1             0-0             1-1
# 12358                  3             0-1             1-3
# 12359                  0             1-0             2-0
# 12360                  3             1-1             2-3
# 12361                  0             0-0             0-0
#
#       time_starting_at_date_time  time_minute  time_injury_time  \
# 12357        2022-04-11 21:00:00           90              <NA>
# 12358        2022-04-15 19:00:00           90              <NA>
# 12359        2022-04-15 21:00:00           90              <NA>
# 12360        2022-04-15 21:00:00           90              <NA>
# 12361        2022-04-15 21:00:00           90              <NA>
#
#        coaches_home_coach_id  coaches_away_coach_id  standings_home_position  \
# 12357               19960388                 524009                       13
# 12358                  95726                 128160                       15
# 12359                 459100                  35571                        2
# 12360                 523953                2158189                        3
# 12361                 530755                 523898                        6
#
#        standings_away_position  assistants_first_assistant_id  \
# 12357                        9                          14349
# 12358                        2                          13402
# 12359                       18                          12816
# 12360                        6                          12253
# 12361                        5                          12257
#
#        assistants_second_assistant_id  assistants_fourth_official_id  \
# 12357                           12225                          50793
# 12358                           12205                          13669
# 12359                           12059                          14082
# 12360                           15840                          17292
# 12361                           13964                          18344
#
#             home_name home_short_code   home_twitter  home_country_id  \
# 12357  Rayo Vallecano             RAY            NaN               32
# 12358          Spezia             SPE      @acspezia              251
# 12359           Milan             MIL       @acmilan              251
# 12360          Rennes             REN  @staderennais               17
# 12361   Real Sociedad             SOC  @RealSociedad               32
#
#        home_founded  home_venue_id   away_name away_short_code away_twitter  \
# 12357          1924         304396    Valencia             VAL  @valenciacf
# 12358          1906           7305       Inter             INT       @Inter
# 12359          1899           1721       Genoa             GEN    @GenoaCFC
# 12360          1901            135      Monaco             AMO   @AS_Monaco
# 12361          1909            133  Real Betis             BET   @RealBetis
#
#        away_country_id  away_founded  away_venue_id  league_country_id  \
# 12357               32          1919           9240                 32
# 12358              251          1908           1721                251
# 12359              251          1893             86                251
# 12360            75285          1919           4451                 17
# 12361               32          1907             68                 32
#
#       league_name  league_is_cup season_name  season_league_id  \
# 12357     La Liga              0   2021/2022               564
# 12358     Serie A              0   2021/2022               384
# 12359     Serie A              0   2021/2022               384
# 12360     Ligue 1              0   2021/2022               301
# 12361     La Liga              0   2021/2022               564
#
#        current_season  round_name  round_league_id  round_season_id  \
# 12357               1          31              564            18462
# 12358               1          33              384            18576
# 12359               1          33              384            18576
# 12360               1          32              301            18441
# 12361               1          32              564            18462
#
#        round_stage_id round_start  round_end              venue_name  \
# 12357        77454016  2022-04-08 2022-04-11     Estadio de Vallecas
# 12358        77454372  2022-04-15 2022-04-18    Stadio Alberto Picco
# 12359        77454372  2022-04-15 2022-04-18  Stadio Giuseppe Meazza
# 12360        77453967  2022-04-15 2022-04-17            Roazhon Park
# 12361        77454016  2022-04-15 2022-04-18             Reale Arena
#
#        venue_grass_surface     venue_city  venue_capacity  \
# 12357                    1         Madrid           14708
# 12358                    0      La Spezia           10336
# 12359                    1         Milano           80018
# 12360                    1         Rennes           29778
# 12361                    1  San Sebastián           32076
#
#            venue_coordinates               referee_fullname  \
# 12357  (40.391808,-3.658611)   Ricardo De Burgos Bengoetxea
# 12358   (44.101711,9.808218)                  Fabio Maresca
# 12359   (45.478025,9.124206)                 Daniele Chiffi
# 12360  (48.107458,-1.712839)             Stéphanie Frappart
# 12361  (43.301376,-1.973602)  Isidro Díaz de Mera Escuderos
#
#        homecoach_coach_id  homecoach_team_id  homecoach_country_id  \
# 12357            19960388                377                    32
# 12358               95726                345                   251
# 12359              459100                113                   251
# 12360              523953                598                    17
# 12361              530755                594                    32
#
#                 homecoach_fullname homecoach_nationality homecoach_birthdate  \
# 12357        Andoni Iraola Sagarna                 Spain          22/06/1982
# 12358                 Thiago Motta                 Italy          28/08/1982
# 12359                Stefano Pioli                 Italy          20/10/1965
# 12360                Bruno Génésio                France          01/09/1966
# 12361  Imanol Alguacil Barrenetxea                 Spain          04/07/1971
#
#       homecoach_birthcountry   homecoach_birthplace  Awaycoach_coach_id  \
# 12357                  Spain                Usurbil              524009
# 12358                 Brazil  São Bernardo do Campo              128160
# 12359                  Italy                  Parma               35571
# 12360                 France                   Lyon             2158189
# 12361                  Spain                   Orio              523898
#
#        Awaycoach_team_id  Awaycoach_country_id  \
# 12357                214                    32
# 12358               2930                   251
# 12359                102                    11
# 12360               6789                   556
# 12361                485                    80
#
#                      Awaycoach_fullname Awaycoach_nationality  \
# 12357             José Bordalás Jiménez                 Spain
# 12358                    Simone Inzaghi                 Italy
# 12359                 Alexander Blessin               Germany
# 12360                  Philippe Clement               Belgium
# 12361  Manuel Luis Pellegrini Ripamonti                 Chile
#
#       Awaycoach_birthdate Awaycoach_birthcountry Awaycoach_birthplace  \
# 12357          05/03/1964                  Spain             Alicante
# 12358          05/04/1976                  Italy             Piacenza
# 12359          28/05/1973                Germany                  NaN
# 12360          22/03/1974                Belgium            Antwerpen
# 12361          16/09/1953                  Chile    Santiago de Chile
#
#       weather_report_code weather_report_type  weather_windspeed(m/s)  \
# 12357              clouds    scattered clouds                   17.27
# 12358               clear           clear sky                    4.27
# 12359               clear           clear sky                    6.91
# 12360               clear           clear sky                    8.05
# 12361              clouds     overcast clouds                    3.00
#
#        weather_report_wind_degree  weather_clouds(%)  weather_humidity(%)  \
# 12357                       240.0                 40                   70
# 12358                       350.0                  3                   51
# 12359                       120.0                  0                   49
# 12360                       310.0                  0                   82
# 12361                       207.0                100                   85
#
#       colors_home_color colors_away_color  weather_report_pressure  \
# 12357           #F0F0F0           #940014                   1007.0
# 12358           #F0F0F0           #002B87                   1013.0
# 12359           #C40010           #CCCCCC                   1018.0
# 12360           #C40010           #F0F0F0                   1026.0
# 12361           #2B72DE           #EA9C08                   1026.0
#
#        weather_report_temperature_celcius_temp  home_team_id  home_fixture_id  \
# 12357                                     14.5           377         18165757
# 12358                                     17.1           345         18220188
# 12359                                     18.5           113         18220185
# 12360                                     13.6           598         18157344
# 12361                                     13.0           594         18165743
#
#        home_shots_total  home_shots_ongoal  home_shots_offgoal  \
# 12357                12                  5                   7
# 12358                11                  3                   8
# 12359                 9                  4                   5
# 12360                14                  4                  10
# 12361                10                  3                   7
#
#        home_shots_blocked  home_shots_insidebox  home_shots_outsidebox  \
# 12357                   0                     5                      6
# 12358                   4                     6                      4
# 12359                   1                     7                      3
# 12360                   3                     7                      6
# 12361                   1                     7                      2
#
#        home_passes  home_attacks  home_fouls  home_corners  home_offsides  \
# 12357         <NA>          <NA>          13             5              4
# 12358         <NA>          <NA>           9             6              1
# 12359         <NA>          <NA>          10             3              3
# 12360         <NA>          <NA>           6             6              0
# 12361         <NA>          <NA>          17             8              7
#
#        home_possessiontime  home_yellowcards  home_redcards  \
# 12357                   56                 3              0
# 12358                   33                 2              0
# 12359                   59                 1              0
# 12360                   64                 1              0
# 12361                   57                 3              1
#
#        home_yellowredcards  home_saves  home_substitutions  home_goal_kick  \
# 12357                    0           1                   4            <NA>
# 12358                    0           4                   5            <NA>
# 12359                    0           2                   5            <NA>
# 12360                    0           1                   4            <NA>
# 12361                    1           2                   6            <NA>
#
#        home_goal_attempts  home_free_kick  home_throw_in  home_ball_safe  \
# 12357                   6            <NA>           <NA>             103
# 12358                   7            <NA>           <NA>             114
# 12359                   7            <NA>           <NA>             108
# 12360                   9            <NA>           <NA>             103
# 12361                   6            <NA>           <NA>              77
#
#        home_goals  home_penalties  home_injuries  home_tackles  away_team_id  \
# 12357           1               0              0            16           214
# 12358           1               0              2            11          2930
# 12359           2               0              3            17           102
# 12360           2               1              1             9          6789
# 12361           0               0           <NA>            16           485
#
#        away_fixture_id  away_shots_total  away_shots_ongoal  \
# 12357         18165757                 7                  2
# 12358         18220188                23                  7
# 12359         18220185                 8                  2
# 12360         18157344                12                  4
# 12361         18165743                 9                  2
#
#        away_shots_offgoal  away_shots_blocked  away_shots_insidebox  \
# 12357                   5                   1                     4
# 12358                  16                   5                    18
# 12359                   6                   1                     3
# 12360                   8                   1                     9
# 12361                   7                   1                     3
#
#        away_shots_outsidebox  away_passes  away_attacks  away_fouls  \
# 12357                      2         <NA>          <NA>          17
# 12358                      5         <NA>          <NA>          11
# 12359                      4         <NA>          <NA>          19
# 12360                      3         <NA>          <NA>          15
# 12361                      6         <NA>          <NA>           7
#
#        away_corners  away_offsides  away_possessiontime  away_yellowcards  \
# 12357             4              0                   44                 4
# 12358             7              1                   67                 0
# 12359             1              1                   41                 2
# 12360             0              1                   36                 3
# 12361             1              3                   43                 4
#
#        away_redcards  away_yellowredcards  away_saves  away_substitutions  \
# 12357              0                    0           3                   5
# 12358              0                    0           1                   5
# 12359              0                    0           3                   5
# 12360              0                    0           2                   3
# 12361              0                    0           2                   5
#
#        away_goal_kick  away_goal_attempts  away_free_kick  away_throw_in  \
# 12357            <NA>                   4            <NA>           <NA>
# 12358            <NA>                  17            <NA>           <NA>
# 12359            <NA>                   5            <NA>           <NA>
# 12360            <NA>                  11            <NA>           <NA>
# 12361            <NA>                   7            <NA>           <NA>
#
#        away_ball_safe  away_goals  away_penalties  away_injuries  \
# 12357             108           1               0              3
# 12358             139           3               0              0
# 12359             102           0               0              2
# 12360              99           3               0              0
# 12361              94           0               0           <NA>
#
#        away_tackles  home_passes_total  home_passes_accurate  \
# 12357            20                432                   314
# 12358            13                275                   190
# 12359            30                498                   412
# 12360            13                668                   569
# 12361            26                477                   408
#
#        home_passes_percentage  away_passes_total  away_passes_accurate  \
# 12357                   72.69                344                   224
# 12358                   69.09                600                   511
# 12359                   82.73                342                   250
# 12360                   85.18                383                   293
# 12361                   85.53                377                   305
#
#        away_passes_percentage  home_attacks_attacks  \
# 12357                   65.12                   115
# 12358                   85.17                    99
# 12359                   73.10                   103
# 12360                   76.50                   125
# 12361                   80.90                   108
#
#        home_attacks_dangerous_attacks  away_attacks_attacks  \
# 12357                              52                   107
# 12358                              33                   114
# 12359                              46                   101
# 12360                              58                    74
# 12361                              78                    95
#
#        away_attacks_dangerous_attacks  home_shots  away_shots  \
# 12357                              38        <NA>        <NA>
# 12358                              69        <NA>        <NA>
# 12359                              30        <NA>        <NA>
# 12360                              33        <NA>        <NA>
# 12361                              37        <NA>        <NA>
#
#           weather_lat_lon Home_ObservationDate   Home_TeamName  Home_Attack  \
# 12357  (40.4165, -3.7026)           2022-03-07  Rayo Vallecano           78
# 12358   (44.1105, 9.8434)           2022-04-11          Spezia           71
# 12359   (45.4643, 9.1895)           2022-04-11           Milan           81
# 12360  (48.1667, -1.6667)           2022-04-11          Rennes           78
# 12361   (43.3128, -1.975)           2022-04-11   Real Sociedad           82
#
#        Home_Midfield  Home_Defence  Home_TransferBudget  \
# 12357             74            73              3300000
# 12358             69            70              2700000
# 12359             80            81             37000000
# 12360             76            76             14000000
# 12361             81            78             15500000
#
#                 Home_RivalTeam  \
# 12357               CD Leganés
# 12358                    Genoa
# 12359                    Inter
# 12360                FC Nantes
# 12361  Athletic Club de Bilbao
#
#                                          Home_TeamRoster  Home_is_major  \
# 12357  ['Stole Dimitrievski', 'Iván Balliu', 'Esteban...              1
# 12358  ['Ivan Provedel', 'Kelvin Amian', 'Martin Erli...              1
# 12359  ['Mike Maignan', 'Davide Calabria', 'Fikayo To...              1
# 12360  ['Alfred Gomis', 'Hamari Traoré', 'Warmed Omar...              1
# 12361  ['Congo', 'Gorosabel', 'Aritz Elustondo', 'Rob...              1
#
#       Away_ObservationDate Away_TeamName  Away_Attack  Away_Midfield  \
# 12357           2022-03-07      Valencia           78             77
# 12358           2022-04-11         Inter           82             82
# 12359           2022-04-11         Genoa           72             72
# 12360           2022-04-11        Monaco           83             78
# 12361           2022-04-11    Real Betis           79             80
#
#        Away_Defence  Away_TransferBudget Away_RivalTeam  \
# 12357            78             60000000     Levante UD
# 12358            83             99500000          Milan
# 12359            72              8500000      Sampdoria
# 12360            76             26000000       OGC Nice
# 12361            78             16000000     Sevilla FC
#
#                                          Away_TeamRoster  Away_is_major
# 12357  ['Giorgi Mamardashvili', 'Thierry Correia', 'G...              1
# 12358  ['Samir Handanovič', 'Milan J. Plada', 'Stefan...              1
# 12359  ['Salvatore Sirigu', 'Silvan Hefti', 'Nikola M...              1
# 12360  ['Alexander NübelL', 'Axel Disasi', 'Guillermo...              1
# 12361  ['Rui Silva', 'Héctor Bellerín MorunoL', 'Germ...              1

# %%
print((final_merged['Home_ObservationDate'] != final_merged['Away_ObservationDate']).sum())
# if any print is different from 0, there is a problem with team coming from a minor league!
# Out:
# 11

# %%
final_merged.to_csv('finalmerge_MATCHES.csv')
